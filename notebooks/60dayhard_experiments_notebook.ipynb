# %% [markdown]
# ## This Jupyter notebook is for propotyping a script that automates the creation of tasks in google calendar

# %%
pip install google-api-python-client

# %%
pip install google-auth-httplib2

# %%
pip install google-auth-oauthlib

# %%
# Install packages
from __future__ import annotations

# %%
import datetime as dt
import os
from typing import Optional, Dict, Any

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# %%
# Google Tasks scope (full access to your Tasks)
SCOPES = ["https://www.googleapis.com/auth/tasks"]

# Name of the task list to create/use
TASKLIST_NAME = "60 Day Hard"
